# %% [markdown]
# # Week 07 Tuesday Submission

# %%
from pathlib import Path
import sys
sys.path.append(str(Path('src').resolve()))
from tuesday_solution import run_pipeline

# %%
run_pipeline(
    reviews_path=Path(r'C:\Users\siddp\Downloads\shopsense_reviews.csv'),
    customers_path=Path(r'C:\Users\siddp\Downloads\shopsense_customers.csv'),
    output_dir=Path('outputs')
)
print('Done')
